# %%
from temboo.Library.Twitter.Users import Lookup
from temboo.core.session import TembooSession

# Create a session with your Temboo account details
session = TembooSession("andreachcode", "myFirstApp", "abkLJYokUhQxwzD5RtoZnKLur8P1pIXK")

# Instantiate the Choreo
lookupChoreo = Lookup(session)

# Get an InputSet object for the Choreo
lookupInputs = lookupChoreo.new_input_set()

# Set the Choreo inputs
lookupInputs.set_UserId("4865738085,135691977,474052193,1538059266,1161907621,1693499504,156810831,4635267749,4850294217,2735808415,3483406572,374190937,4105548635,3313157675,4814656685,4760827218,4102852105,4717702119,852241,252723584,3314202313,3862013063,18784088,1870319041,17928145,2545050195,440519278,3214472661,3833101324,4000917556,18909605,2866489102,4190752216,3774689415,137788484,2782589658,2375531444,206163060,2499737527,17539984,615343292,161429642,3242698644,15298979,238437242,1911459386,1215532796,1301891509,2987359185,113234153,2923684513,52427025,2517554893,2586264426,2418098766,17322794,848270365,3336652331,1446051,31223005,16305330,2151538954,27305797,7858302,3129294153,436318060,446506935,432432520,2218902493,3061734398,318895578,766367078,3070398000,54783663,25363043,1909376407,2327435180,174701460,60693412,560787815,57158676,3321178215,88243388,12308932,8596022,30670565,1112290681,3302248564")
lookupInputs.set_AccessToken("1149515354-E1ERXrHTnBohJdDhdVyGwVgNRLPKUZTrEW6WfaF")
lookupInputs.set_ConsumerKey("WbWdJS6NKlW8gtYaxnreIKMig")
lookupInputs.set_ConsumerSecret("R0T9unRcsDDv1Tot2aY6JqcXjWVpKrHxDtg5Z8RsYUZeVLsjun")
lookupInputs.set_AccessTokenSecret("57gJuU81rAMYfmnU2ut8ssHKnAbUbL5j6DK5shR5a1dHL")

# Execute the Choreo
lookupResults = lookupChoreo.execute_with_results(lookupInputs)

# Print the Choreo outputs
print("Limit: " + lookupResults.get_Limit())
print("Remaining: " + lookupResults.get_Remaining())
print("Reset: " + lookupResults.get_Reset())
print("Response: " + lookupResults.get_Response())
# Out:
# Limit: 180
# Remaining: 177
# Reset: 1459427822
# ...
