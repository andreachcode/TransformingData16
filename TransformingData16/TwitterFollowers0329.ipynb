# %%
from temboo.Library.Twitter.Users import Lookup
from temboo.core.session import TembooSession

# Create a session with your Temboo account details
session = TembooSession("andreachcode", "myFirstApp", "abkLJYokUhQxwzD5RtoZnKLur8P1pIXK")

# Instantiate the Choreo
lookupChoreo = Lookup(session)

# Get an InputSet object for the Choreo
lookupInputs = lookupChoreo.new_input_set()

# Set the Choreo inputs
lookupInputs.set_AccessToken("1149515354-E1ERXrHTnBohJdDhdVyGwVgNRLPKUZTrEW6WfaF")
lookupInputs.set_ConsumerKey("WbWdJS6NKlW8gtYaxnreIKMig")
lookupInputs.set_UserId("712228578419728384,710785391041716225,28669792,580847938,3309528800,710816250155302912,709673241544097792,4254451342,24889998,882192152,3166266780,4174293550,3170504543,2166490562,709186020823212036,2163912128,1539525206,48621400,2604068238,1694863603,4833195191,4346058443,4634832325,92199427,4347461,14243746,4129455374,")
lookupInputs.set_ConsumerSecret("R0T9unRcsDDv1Tot2aY6JqcXjWVpKrHxDtg5Z8RsYUZeVLsjun")
lookupInputs.set_AccessTokenSecret("57gJuU81rAMYfmnU2ut8ssHKnAbUbL5j6DK5shR5a1dHL")

# Execute the Choreo
lookupResults = lookupChoreo.execute_with_results(lookupInputs)

# Print the Choreo outputs
print("Limit: " + lookupResults.get_Limit())
print("Remaining: " + lookupResults.get_Remaining())
print("Reset: " + lookupResults.get_Reset())
print("Response: " + lookupResults.get_Response())
# Out:
# Limit: 180
# Remaining: 175
# Reset: 1459276887
# ...

# %%
#Lists

friends = {45, 3039, 8193, 173545, 4050, 3070, 4565, 26923, 28212, 4918, }
months = {0.1, 0.1, 83, 46, 7, 0.1, 4, 84, 41, 11}
listed = {0, 4, 117, 104, 38, 0, 69, 1322, 2896, 17}
statuses = {2, 4255, 94585, 1590, 671, 4265, 248, 13107, 112473, 3593}
followers = {0, 293, 9047, 178982, 3818, 259, 2274, 29533, 99042, 3593}

average = 0
sum = 0
for n in friends:
    sum = sum + n
    average = sum/len(friends)
print(average)

average = 0
sum = 0
for n in months:
    sum = sum + n
    average = sum/len(months)
print(average)

average = 0
sum = 0
for n in listed:
    sum = sum + n
    average = sum/len(listed)
print(average)

average = 0
sum = 0
for n in statuses:
    sum = sum + n
    average = sum/len(statuses)
print(average)

average = 0
sum = 0
for n in followers:
    sum = sum + n
    average = sum/len(followers)
print(average)

friendsr = np.ptp(friends, axis=1)
# Out:
# 25656.0
# 34.5125
# 507.44444444444446
# 23478.9
# 32684.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Andrea\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in ptp(a, axis, out)
#    2168     try:
# -> 2169         ptp = a.ptp
#    2170     except AttributeError:
#
# AttributeError: 'set' object has no attribute 'ptp'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0fb554beb80a> in <module>()
#      42 print(average)
#      43
# ---> 44 friendsr = np.ptp(friends, axis=1)
#
# C:\Users\Andrea\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in ptp(a, axis, out)
#    2169         ptp = a.ptp
#    2170     except AttributeError:
# -> 2171         return _wrapit(a, 'ptp', axis, out)
#    2172     return ptp(axis, out)
#    2173
#
# ...

# %%
import numpy as np
np
f = ([45, 3039, 8193, 173545, 4050, 3070, 4565, 26923, 28212, 4918])
f
np.median(f)

m = ([0.1, 0.1, 83, 46, 7, 0.1, 4, 84, 41, 11])
m
np.median(m)

l = ([0, 4, 117, 104, 38, 0, 69, 1322, 2896, 17])
l
np.median(l)

s = ([2, 4255, 94585, 1590, 671, 4265, 248, 13107, 112473, 3593])
s
np.median(s)

fol = ([0, 293, 9047, 178982, 3818, 259, 2274, 29533, 99042, 3593])
fol
np.median(fol)

# %%
pfollowers = [2062, 32640, 320, 19, 273, 55, 14691, 86430, 617, 329]
pfriends = [2988, 26882, 1966, 159, 1417, 287, 3432, 76602, 1806, 4996]
plisted = [285, 44, 1, 0, 1, 3, 102, 985, 254, 155]
pmonths = [4, 11, 28, 1, 28, 33, 81, 21, 31, 2]
pstatuses = [1981, 98, 125, 5, 85, 114, 1757, 425, 27855, 155]

average = 0
sum = 0
for n in pfollowers:
    sum = sum + n
    average = sum/len(pfollowers)
print(average)

average = 0
sum = 0
for n in pfriends:
    sum = sum + n
    average = sum/len(pfriends)
print(average)

average = 0
sum = 0
for n in plisted:
    sum = sum + n
    average = sum/len(plisted)
print(average)

average = 0
sum = 0
for n in pmonths:
    sum = sum + n
    average = sum/len(pmonths)
print(average)

average = 0
sum = 0
for n in pstatuses:
    sum = sum + n
    average = sum/len(pstatuses)
print(average)
# Out:
# 13743.6
# 12053.5
# 183.0
# 24.0
# 3260.0

# %%
import numpy as np
np
fp = ([2988, 26882, 1966, 159, 1417, 287, 3432, 76602, 1806, 4996])
f
np.median(fp)

folp = ([2062, 32640, 320, 19, 273, 55, 14691, 86430, 617, 329])
f
np.median(folp)

mp = ([4, 11, 28, 1, 28, 33, 81, 21, 31, 2])
f
np.median(mp)


mp = ([4, 11, 28, 1, 28, 33, 81, 21, 31, 2])
f
np.median(mp)
# Out:
# 24.5
